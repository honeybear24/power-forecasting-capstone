# %%
import pandas as pd
import datetime
from datetime import datetime, date, timedelta
import matplotlib.pyplot as plt
import os
import math
import numpy as np
import canada_holiday
import joblib  # To load the scaler

import seaborn as sns
from sklearn import preprocessing

from pyhelpers.store import save_fig, save_svg_as_emf
import subprocess
import  aspose.cells 
from aspose.cells import Workbook

# %%
#%% Student directory
hanad_run = ["./data", 1]
clover_run = ["./data", 2]
joseph_laptop_run = ["C:\\Users\\sposa\\Documents\\GitHub\\power-forecasting-capstone\\data", 3]
joseph_pc_run = ["D:\\Users\\Joseph\\Documents\\GitHub\\power-forecasting-capstone\\data", 3]
janna_run = ["../data", 4]

###############################################################################
############### MAKE SURE TO CHANGE BEFORE RUNNING CODE #######################
###############################################################################
# Paste student name_run for whoever is running the code
run_student = janna_run
if (run_student[1] == joseph_laptop_run[1]):
    print("JOSEPH IS RUNNING!")
elif (run_student[1] == hanad_run[1]):
    print("HANAD IS RUNNING!")
elif (run_student[1] == janna_run[1]):
    print("JANNA IS RUNNING!")
elif (run_student[1] == clover_run[1]):
    print("CLOVER IS RUNNING!")
else:
    print("ERROR!! NO ELIGIBLE STUDENT!")
            
#%% User input

# FSA - Forward Section Area (first 3 characters of Postal Code)
#       L8K = Neighborhood in Hamilton (Link to FSA Map: https://www.prospectsinfluential.com/wp-content/uploads/2017/09/Interactive-Canadian-FSA-Map.pdf)
fsa_list = ['L9G']

# GUI INPUT
fsa_chosen = "L9G"

years = ['2018', '2019', '2020', '2021', '2022', '2023']
#years = ['2018']

# Jan - 01
# Feb - 02
# Mar - 03
# Apr - 04
# May - 05
# Jun - 06
# Jul - 07
# Aug - 08
# Sep - 09
# Oct - 10
# Nov - 11
# Dec - 12
months = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

months_name = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

#%% Input files (PRE-PROCESSING)
dirs_inputs = run_student[0]

dirs_hourly_consumption_demand = os.path.join(dirs_inputs, "Hourly_Demand_Data")

###############################################################################
# Dictionary for reading in hourly consumption by FSA
###############################################################################
# FSA -> Year -> Month -> Value
hourly_consumption_data_dic_by_month = {}

for fsa in fsa_list:
    hourly_consumption_data_dic_by_month[fsa] = {} # Initialize FSA dictionary
    for year in years:
        hourly_consumption_data_dic_by_month[fsa][year] = {} # Initialize yearly dictionary
        
        for month in months:
            hourly_consumption_data_dic_by_month[fsa][year][month] = {} # Initialize monthly dictionary
            
            # Initialize dataframes to be used
            hourly_data_date = pd.DataFrame()
            hourly_data_res = pd.DataFrame()
            hourly_data_res_fsa = pd.DataFrame()
            hourly_data_hour_sum = pd.DataFrame()
            
            hourly_data_string = "PUB_HourlyConsumptionByFSA_"+year+month+"_v1.csv"
            
            # Use try and catch if problems reading input data
            try:
                # Not cooked yet, we are going to let it COOK below
                file_path = os.path.join(dirs_hourly_consumption_demand, hourly_data_string)
                hourly_data_raw = pd.read_csv(file_path, skiprows=3, header = 0, usecols= ['FSA', 'DATE', 'HOUR', 'CUSTOMER_TYPE', 'TOTAL_CONSUMPTION'])
            except FileNotFoundError: # not all months had a file (for example, 2024 only has up to may)
                continue
            except ValueError: # skiprows=x does not match the "normal sequence" of 3. For example, 2023 08 data had a different skip_row value
                hourly_data_raw = pd.read_csv(file_path, skiprows=7, header = 0, usecols= ['FSA', 'DATE', 'HOUR', 'CUSTOMER_TYPE', 'TOTAL_CONSUMPTION'])
       
            # Convert Date into year, month, day
            hourly_data_fix_date = hourly_data_raw
            hourly_data_fix_date['DATE'] = pd.to_datetime(hourly_data_raw['DATE'])
            hourly_data_fix_date['YEAR'] = hourly_data_fix_date['DATE'].dt.year
            hourly_data_fix_date['MONTH'] = hourly_data_fix_date['DATE'].dt.month
            hourly_data_fix_date['DAY'] = hourly_data_fix_date['DATE'].dt.day
            
            # Filter out only residential data
            hourly_data_res = hourly_data_fix_date.loc[hourly_data_fix_date['CUSTOMER_TYPE'] == "Residential"].reset_index(drop=True)
            
            # Then filter out by the fsa
            hourly_data_res_fsa = hourly_data_res.loc[hourly_data_res['FSA'] == fsa].reset_index(drop=True)
            
            # Take the sum if fsa has more than 1 date (this is because there are different pay codes in residential loads)
            hourly_data_hour_sum = hourly_data_res_fsa.groupby(["FSA", "CUSTOMER_TYPE", "YEAR", "MONTH", "DAY", "HOUR", "DATE"]).TOTAL_CONSUMPTION.sum().reset_index()
            
            
            hourly_consumption_data_dic_by_month[fsa][year][month] = hourly_data_hour_sum
            
            
            print(hourly_data_string)

###############################################################################
# Conversion between FSA and latitude longitude - NOT IMPORTANT NOW
###############################################################################
dirs_hourly_weather = os.path.join(dirs_inputs, "Weather_Data\\Hamilton_Weather\\")

###############################################################################
# Dictionary for reading in weather data
###############################################################################
# FSA -> Year -> Month -> Value

hourly_weather_data_dic_by_month = {}

for fsa in fsa_list:
    hourly_weather_data_dic_by_month[fsa] = {} # Initialize FSA dictionary
    for year in years:
        hourly_weather_data_dic_by_month[fsa][year] = {} # Initialize yearly dictionary
        
        for month in months:
            hourly_weather_data_dic_by_month[fsa][year][month] = {} # Initialize monthly dictionary
            
            # # Initialize dataframes to be used
            # hourly_data_date = pd.DataFrame()
            # hourly_data_res = pd.DataFrame()
            # hourly_data_res_fsa = pd.DataFrame()
            # hourly_data_hour_sum = pd.DataFrame()
            climate_id = "6153193"
            weather_data_string = "en_climate_hourly_ON_" + climate_id + "_" + month + "-" + year + "_P1H.csv"
            
            # Use try and catch if problems reading input data
            try:
                # Not cooked yet, we are going to let it COOK below
                ## TO DO: Calculate Hmdx using existing data (Link: https://weather.mcmaster.ca/parameter_calculation)
                file_path = os.path.join(dirs_hourly_weather, weather_data_string)
                hourly_data_raw = pd.read_csv(file_path, skiprows=0, header = 0, usecols= ['Climate ID', 'Date/Time (LST)', 'Temp (°C)', 'Dew Point Temp (°C)', 'Rel Hum (%)', 'Wind Dir (10s deg)', 'Wind Spd (km/h)', 'Visibility (km)', 'Stn Press (kPa)', 'Wind Chill', 'Weather'])
            except FileNotFoundError: # not all months had a file (for example, 2024 only has up to may)
                continue
            # except ValueError: # skiprows=x does not match the "normal sequence" of 3. For example, 2023 08 data had a different skip_row value
            #     hourly_data_raw = pd.read_csv(dirs_hourly_weather+weather_data_string, skiprows=7, header = 0, usecols= ['FSA', 'DATE', 'HOUR', 'CUSTOMER_TYPE', 'TOTAL_CONSUMPTION'])
       
            # Convert Date into year, month, day
            hourly_data_fix_date = hourly_data_raw
            hourly_data_fix_date['DATE'] = pd.to_datetime(hourly_data_raw['Date/Time (LST)'])
            hourly_data_fix_date['YEAR'] = hourly_data_fix_date['DATE'].dt.year
            hourly_data_fix_date['MONTH'] = hourly_data_fix_date['DATE'].dt.month
            hourly_data_fix_date['DAY'] = hourly_data_fix_date['DATE'].dt.day
            hourly_data_fix_date['HOUR'] = hourly_data_fix_date['DATE'].dt.hour
            hourly_data_fix_date['HOUR'] = hourly_data_fix_date['HOUR']+1  
    
            # Manual Calculation for WindChill
            hourly_data_fix_date['WIND CHILL CALCULATION'] = 13.12 + hourly_data_fix_date['Temp (°C)']*0.6125 - 11.37 * hourly_data_fix_date['Wind Spd (km/h)']**0.16 + 0.3965 * hourly_data_fix_date['Temp (°C)'] * hourly_data_fix_date['Wind Spd (km/h)']**0.16
            
            # Change Temperature column names so it does not have symbols anymore
            hourly_data_fix_date.rename(columns = {'Temp (°C)':'Temp (C)', 'Dew Point Temp (°C)':'Dew Point Temp (C)'}, inplace = True)
            
            hourly_weather_data_dic_by_month[fsa][year][month] = hourly_data_fix_date
            
            print(weather_data_string)

###############################################################################
# Calendar Variables
###############################################################################

# Add weekdays to hourly consumption dataframe
# Monday = 0 
# Tuesday = 1
# Wednesday = 2
# Thursday = 3
# Friday = 4 
# Saturday = 5
# Sunday = 6

# Add season to hourly consumption dataframe
# As per OEB:
# Winter(1) = November (Including) to April (Including)
# Summer(0) = May (Including) to October (Including)
for year in years:        
    for month in months:
        try:
            # Get day of week and check if it is a weekend or weekday
            hourly_consumption_data_dic_by_month[fsa_chosen][year][month]["DAY_OF_WEEK"] = hourly_consumption_data_dic_by_month[fsa_chosen][year][month]["DATE"].dt.weekday
            hourly_consumption_data_dic_by_month[fsa_chosen][year][month]["WEEKEND"] = hourly_consumption_data_dic_by_month[fsa_chosen][year][month]["DAY_OF_WEEK"]>4
            hourly_consumption_data_dic_by_month[fsa_chosen][year][month]["WEEKDAY"] = hourly_consumption_data_dic_by_month[fsa_chosen][year][month]["DAY_OF_WEEK"]<5
            
            # Convert boolean of weekend or weekday to integer numbers (1-True, 0-False)
            hourly_consumption_data_dic_by_month[fsa_chosen][year][month]["WEEKEND"] = hourly_consumption_data_dic_by_month[fsa_chosen][year][month]["WEEKEND"].astype(int)
            hourly_consumption_data_dic_by_month[fsa_chosen][year][month]["WEEKDAY"] = hourly_consumption_data_dic_by_month[fsa_chosen][year][month]["WEEKDAY"].astype(int)
            
            # Get Season and check if it is winter or summer
            hourly_consumption_data_dic_by_month[fsa_chosen][year][month]["SEASON"] = (hourly_consumption_data_dic_by_month[fsa_chosen][year][month]["MONTH"]<5) | (hourly_consumption_data_dic_by_month[fsa_chosen][year][month]["MONTH"]>10)
            
            # Convert boolean of weekend or weekday to integer numbers (1-Winter, 0-Summer)
            hourly_consumption_data_dic_by_month[fsa_chosen][year][month]["SEASON"] = hourly_consumption_data_dic_by_month[fsa_chosen][year][month]["SEASON"].astype(int)
            
            
            
            
            # Pad the holiday column with zeros to initialize it
            hourly_consumption_data_dic_by_month[fsa_chosen][year][month]["HOLIDAY"] = 0
            
            for index, row in  hourly_consumption_data_dic_by_month[fsa_chosen][year][month].iterrows():
                date_temp = date(row["YEAR"], row["MONTH"], row["DAY"])
                if (row["HOUR"] == 1):
                    if canada_holiday.is_holiday(date_temp, "Ontario"):
                        hourly_consumption_data_dic_by_month[fsa_chosen][year][month].loc[index, "HOLIDAY"] = 1
                        temp_value = 1
                    else:
                        temp_value = 0
                else:
                    hourly_consumption_data_dic_by_month[fsa_chosen][year][month].loc[index, "HOLIDAY"] = temp_value
        except KeyError:
            continue

###############################################################################
# X and Y Dataframes
###############################################################################
X_df = pd.DataFrame()
Y_df = pd.DataFrame()

# Combine hourly data by month into the X_df
for year in years:        
    for month in months:
        try:
            # Extract the monthly hourly data for x variables
            hourly_data_consumption_by_month_X = hourly_consumption_data_dic_by_month[fsa_chosen][year][month].drop(["FSA", "CUSTOMER_TYPE", "TOTAL_CONSUMPTION", "DATE"], axis=1)
            hourly_data_weather_by_month_X = hourly_weather_data_dic_by_month[fsa_chosen][year][month].drop(['Climate ID', 'Date/Time (LST)', 'Wind Dir (10s deg)', 'Visibility (km)', 'Stn Press (kPa)', 'Weather', 'DATE', 'YEAR', 'MONTH', 'DAY', 'HOUR'], axis=1)
            
            
            # Combine all hourly data for x variables
            hourly_data_by_month_X = pd.concat([hourly_data_consumption_by_month_X, hourly_data_weather_by_month_X], axis = 1)
            
            # Extract the monthly hourly data for y variables
            hourly_data_by_month_Y = hourly_consumption_data_dic_by_month[fsa_chosen][year][month].drop(["FSA", "CUSTOMER_TYPE", "DATE", "DAY_OF_WEEK", "WEEKEND", "WEEKDAY", "SEASON", "HOLIDAY"], axis=1)
            
            
            X_df = pd.concat([X_df, hourly_data_by_month_X], ignore_index=True)
            Y_df = pd.concat([Y_df, hourly_data_by_month_Y], ignore_index=True)
        except KeyError:
            continue

###############################################################################
# Cleaning up X_df dataframe
###############################################################################

# Exclude "Wind Chill" column
X_without_bad_windchill = X_df.drop(columns="Wind Chill")

## Smooth out missing data
#    METHOD FOR MISSING WEATHER DATA: If value is blank, set black as average of pervious and next values
# Get columns in dataframe and cycle through them in a for loop
X_columns = X_without_bad_windchill.columns
for column in X_columns:
    # Skip over date/time columns
    if column == "YEAR" or column == "MONTH" or column == "DAY" or column == "HOUR":
        continue

    #print("Current Column: " + column) # Checking what columns make it here
    #print("\n")
    counter_adjacent_nan = 0
    # For current column, iterate through all rough
    for index, row in X_without_bad_windchill.iterrows():
        # Check if there are more than 2 nan values
        if (counter_adjacent_nan>1):
            counter_adjacent_nan -= 1
            continue
        # Check if value for current index and column is missing
        #if row[column] != row[column]:
        if math.isnan(row[column]):
            #print("MISSING DATA FOUND AT Index: " , str(index) , " | Column: " + column + " | Value: " + str(row[column]))
            
            # If found, take need to take linear interpolation between last actual value and next actual value (need to interpolate any consectutively missing data points too!)
            # Finding last actual data point
            last_data_point = X_without_bad_windchill.loc[index-1, column]
            #print("Last viable data point: " + str(last_data_point)  + "\n")
            
            # Find next available data point
            counter = 0
            not_found = True
            while not_found == True:
                counter += 1

                try: # Try to get value of next data point
                    next_data_point = X_without_bad_windchill.loc[index+counter, column]
                except KeyError: # If there are NaN values at the end of the data frame, set the value of the next data point to be eqaul last data point
                    next_data_point = last_data_point

                # Check if variable is a real value (NaN values wil ALWAYS fail this condition)
                if next_data_point == next_data_point:
                    # If found, set not_found to False and leave loop
                    not_found = False
            
            # Get linear interpolation of data
            interpolated_data = np.linspace(start=last_data_point, stop=next_data_point, num=counter+1, endpoint = False)[1:]
            

            # Give interpolated values to missing data points
            counter = 0
            counter_adjacent_nan=0
            for new_value in interpolated_data:
                X_without_bad_windchill.loc[index+counter, column] = new_value
                #print(" NEW INTERPOLATED VALUE = " + str(X_without_bad_windchill.loc[index+counter, column]))
                counter += 1
                counter_adjacent_nan += 1
X_df_cleaned = X_without_bad_windchill

# Add Date back into X_df_cleaned variable
X_df_cleaned["DATE"] = 0
for index, row in  X_df_cleaned.iterrows():
    X_df_cleaned.loc[index, "DATE"] = date(int(row["YEAR"]),int(row["MONTH"]),int(row["DAY"]))

# Convert year, month, day, hour to boolean values

# Day range 1 to 31
days = [*range(1, 32)]
# Hour range 1 to 24
hours = [*range(1, 25)]

for year in years:
    X_df_cleaned[year] = X_df_cleaned["YEAR"]==int(year)
    X_df_cleaned[year] = X_df_cleaned[year].astype(int)

for month in months_name:
    X_df_cleaned[month] = X_df_cleaned["MONTH"]==int(months_name.index(month)+1)
    X_df_cleaned[month] = X_df_cleaned[month].astype(int)

for day in days:
    X_df_cleaned["DAY_"+str(day)] = X_df_cleaned["DAY"]==int(day)
    X_df_cleaned["DAY_"+str(day)] = X_df_cleaned["DAY_"+str(day)].astype(int)

for hour in hours:
    X_df_cleaned["HOUR_"+str(hour)] = X_df_cleaned["HOUR"]==int(hour)
    X_df_cleaned["HOUR_"+str(hour)] = X_df_cleaned["HOUR_"+str(hour)].astype(int)

X_df_cleaned_output = X_df_cleaned.drop(['YEAR', 'MONTH', 'DAY', 'HOUR', 'DATE', 'WEEKDAY', 'DAY_OF_WEEK'], axis=1)

###############################################################################
# Export X and Y Dataframes to CSV
###############################################################################
dirs_dataframes = os.path.join(dirs_inputs, "X_Y_Inputs")
X_df_output_string =  os.path.join(dirs_dataframes, "X_df_"+fsa_chosen+".csv")
X_df_cleaned_output.to_csv(X_df_output_string, index=False)
Y_df_output_string =  os.path.join(dirs_dataframes, "Y_df_"+fsa_chosen+".csv")
Y_df["TOTAL_CONSUMPTION"].to_csv(Y_df_output_string, index=False)
# Out:
# JANNA IS RUNNING!
# PUB_HourlyConsumptionByFSA_201801_v1.csv
# PUB_HourlyConsumptionByFSA_201802_v1.csv
# PUB_HourlyConsumptionByFSA_201803_v1.csv
# PUB_HourlyConsumptionByFSA_201804_v1.csv
# PUB_HourlyConsumptionByFSA_201805_v1.csv
# PUB_HourlyConsumptionByFSA_201806_v1.csv
# PUB_HourlyConsumptionByFSA_201807_v1.csv
# PUB_HourlyConsumptionByFSA_201808_v1.csv
# PUB_HourlyConsumptionByFSA_201809_v1.csv
# PUB_HourlyConsumptionByFSA_201810_v1.csv
# PUB_HourlyConsumptionByFSA_201811_v1.csv
# PUB_HourlyConsumptionByFSA_201812_v1.csv
# PUB_HourlyConsumptionByFSA_201901_v1.csv
# PUB_HourlyConsumptionByFSA_201902_v1.csv
# PUB_HourlyConsumptionByFSA_201903_v1.csv
# PUB_HourlyConsumptionByFSA_201904_v1.csv
# PUB_HourlyConsumptionByFSA_201905_v1.csv
# PUB_HourlyConsumptionByFSA_201906_v1.csv
# PUB_HourlyConsumptionByFSA_201907_v1.csv
# PUB_HourlyConsumptionByFSA_201908_v1.csv
# PUB_HourlyConsumptionByFSA_201909_v1.csv
# PUB_HourlyConsumptionByFSA_201910_v1.csv
# PUB_HourlyConsumptionByFSA_201911_v1.csv
# PUB_HourlyConsumptionByFSA_201912_v1.csv
# PUB_HourlyConsumptionByFSA_202001_v1.csv
# PUB_HourlyConsumptionByFSA_202002_v1.csv
# PUB_HourlyConsumptionByFSA_202003_v1.csv
# PUB_HourlyConsumptionByFSA_202004_v1.csv
# PUB_HourlyConsumptionByFSA_202005_v1.csv
# PUB_HourlyConsumptionByFSA_202006_v1.csv
# PUB_HourlyConsumptionByFSA_202007_v1.csv
# PUB_HourlyConsumptionByFSA_202008_v1.csv
# PUB_HourlyConsumptionByFSA_202009_v1.csv
(s) in Canada
# Getting holiday information of Ontario province...
# 2018-01-02 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-03 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-04 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-05 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-06 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-07 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-08 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-09 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-10 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-11 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-12 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-13 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-14 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-15 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-16 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-17 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-18 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-19 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-20 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-21 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-22 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-23 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-24 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-25 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-26 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-27 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-28 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-29 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-30 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-01-31 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-01 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-02 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-03 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-04 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-05 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-06 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-07 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-08 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-09 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-10 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-11 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-12 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-13 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-14 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-15 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-16 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-17 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-18 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-19 is a holiday, Family Day in Ontario province(s) in Canada
# Getting holiday information of Ontario province...
# 2018-02-20 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-21 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-22 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-23 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-24 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-25 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-26 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-27 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-02-28 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-01 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-02 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-03 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-04 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-05 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-06 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-07 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-08 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-09 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-10 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-11 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-12 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-13 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-14 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-15 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-16 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-17 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-18 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-19 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-20 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-21 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-22 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-23 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-24 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-25 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-26 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-27 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-28 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-29 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-03-30 is a holiday, Good Friday in Ontario province(s) in Canada
# Getting holiday information of Ontario province...
# 2018-03-31 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# 2018-05-01 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-02 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-03 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-04 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-05 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-06 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-07 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-08 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-09 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-10 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-11 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-12 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-13 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-14 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-15 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-16 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-17 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-18 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-19 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-20 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-21 is a holiday, Victoria Day in Ontario province(s) in Canada
# Getting holiday information of Ontario province...
# 2018-05-22 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-23 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-24 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-25 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-26 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-27 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-28 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-29 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-30 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-05-31 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# 2018-07-01 is a holiday, Canada Day in all province(s) in Canada
# Getting holiday information of Ontario province...
# 2018-07-02 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-03 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-04 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-05 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-06 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-07 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-08 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-09 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-10 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-11 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-12 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-13 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-14 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-15 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-16 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-17 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-18 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-19 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-20 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-21 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-22 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-23 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-24 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-25 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-26 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-27 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-28 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-29 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-30 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-07-31 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-01 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-02 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-03 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-04 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-05 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-06 is a holiday, Civic Holiday in Ontario province(s) in Canada
# Getting holiday information of Ontario province...
# 2018-08-07 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-08 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-09 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-10 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-11 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-12 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-13 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-14 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-15 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-16 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-17 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-18 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-19 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-20 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-21 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-22 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-23 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-24 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-25 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-26 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-27 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-28 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-29 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-30 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-08-31 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-01 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-02 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-03 is a holiday, Labour Day in all province(s) in Canada
# Getting holiday information of Ontario province...
# 2018-09-04 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-05 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-06 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-07 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-08 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-09 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-10 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-11 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-12 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-13 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-14 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-15 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-16 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-17 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-18 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-19 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-20 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-21 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-22 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-23 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-24 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-25 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-26 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-27 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-28 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-29 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-09-30 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-01 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-02 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-03 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-04 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-05 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-06 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-07 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-08 is a holiday, Thanksgiving Day in Ontario province(s) in Canada
# Getting holiday information of Ontario province...
# 2018-10-09 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-10 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-11 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-12 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-13 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-14 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-15 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-16 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-17 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-18 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-19 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-20 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-21 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-22 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-23 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-24 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-25 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-26 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-27 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-28 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-29 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-30 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-10-31 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# 2018-12-01 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-02 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-03 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-04 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-05 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-06 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-07 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-08 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-09 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-10 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-11 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-12 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-13 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-14 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-15 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-16 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-17 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-18 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-19 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-20 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-21 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-22 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-23 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-24 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-25 is a holiday, Christmas Day in all province(s) in Canada
# Getting holiday information of Ontario province...
# 2018-12-26 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-27 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-28 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-29 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-30 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2018-12-31 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-01 is a holiday, New Year's Day in all province(s) in Canada
# Getting holiday information of Ontario province...
# 2019-01-02 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-03 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-04 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-05 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-06 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-07 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-08 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-09 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-10 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-11 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-12 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-13 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-14 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-15 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-16 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-17 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-18 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-19 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-20 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-21 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-22 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-23 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-24 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-25 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-26 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-27 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-28 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-29 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-30 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-01-31 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-01 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-02 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-03 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-04 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-05 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-06 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-07 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-08 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-09 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-10 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-11 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-12 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-13 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-14 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-15 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-16 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-17 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-18 is a holiday, Family Day in Ontario province(s) in Canada
# Getting holiday information of Ontario province...
# 2019-02-19 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-20 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-21 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-22 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-23 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-24 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-25 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-26 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-27 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-02-28 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# 2019-04-01 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-04-02 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-04-03 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-04-04 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-04-05 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-04-06 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-04-07 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-04-08 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-04-09 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-04-10 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-04-11 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-04-12 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-04-13 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-04-14 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-04-15 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-04-16 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-04-17 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-04-18 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2019-04-19 is a holiday, Good Friday in Ontario province(s) in Canada
# Getting holiday information of Ontario province...
# ...
# 2023-07-15 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-07-16 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-07-17 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-07-18 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-07-19 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-07-20 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-07-21 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-07-22 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-07-23 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-07-24 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-07-25 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-07-26 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-07-27 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-07-28 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-07-29 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-07-30 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-07-31 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-01 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-02 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-03 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-04 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-05 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-06 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-07 is a holiday, Civic Holiday in Ontario province(s) in Canada
# Getting holiday information of Ontario province...
# 2023-08-08 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-09 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-10 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-11 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-12 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-13 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-14 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-15 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-16 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-17 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-18 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-19 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-20 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-21 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-22 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-23 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-24 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-25 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-26 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-27 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-28 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-29 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-30 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-08-31 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-01 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-02 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-03 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-04 is a holiday, Labour Day in all province(s) in Canada
# Getting holiday information of Ontario province...
# 2023-09-05 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-06 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-07 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-08 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-09 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-10 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-11 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-12 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-13 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-14 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-15 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-16 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-17 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-18 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-19 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-20 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-21 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-22 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-23 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-24 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-25 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-26 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-27 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-28 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-29 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-09-30 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-01 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-02 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-03 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-04 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-05 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-06 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-07 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-08 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-09 is a holiday, Thanksgiving Day in Ontario province(s) in Canada
# Getting holiday information of Ontario province...
# 2023-10-10 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-11 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-12 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-13 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-14 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-15 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-16 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-17 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-18 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-19 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-20 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-21 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-22 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-23 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-24 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-25 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-26 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-27 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-28 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-29 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-30 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-10-31 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# Getting holiday information of Ontario province...
# 2023-12-01 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-02 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-03 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-04 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-05 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-06 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-07 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-08 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-09 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-10 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-11 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-12 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-13 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-14 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-15 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-16 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-17 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-18 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-19 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-20 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-21 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-22 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-23 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-24 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-25 is a holiday, Christmas Day in all province(s) in Canada
# Getting holiday information of Ontario province...
# 2023-12-26 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-27 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-28 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-29 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-30 is not a holiday in Ontario province.
# Getting holiday information of Ontario province...
# 2023-12-31 is not a holiday in Ontario province.
# C:\Users\janna\AppData\Local\Temp\ipykernel_17396\1300456599.py:318: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2018-01-01' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_df_cleaned.loc[index, "DATE"] = date(int(row["YEAR"]),int(row["MONTH"]),int(row["DAY"]))

# %% [markdown]
# Normalizing X_df

# %%
# Select the columns to normalize (4th to 8th columns)
columns_to_normalize = X_df_cleaned_output.columns[3:8]  # Adjust index as needed

min_max_scaler = preprocessing.MinMaxScaler()

# Normalize the selected columns
X_minmax = X_df_cleaned_output.copy()  # Create a copy to avoid modifying the original DataFrame
X_minmax[columns_to_normalize] = min_max_scaler.fit_transform(X_df_cleaned_output[columns_to_normalize])

# Save the normalized DataFrame to a new DataFrame
X_minmax_df = X_minmax

# Specify the correct path for saving the CSV
dirs_dataframes = os.path.join(dirs_inputs, "X_Y_Inputs")
X_train_minmax_output_string = os.path.join(dirs_dataframes, "X_df_normalized.csv")

# Save the DataFrame to CSV
X_minmax_df.to_csv(X_train_minmax_output_string, index=False)

# %% [markdown]
# Normalizing Y_df

# %%
# Create a new DataFrame with only the TOTAL_CONSUMPTION column
Y_df_total_consumption = Y_df[['TOTAL_CONSUMPTION']].copy()  # Ensure it's a DataFrame

# Create a MinMaxScaler instance
min_max_scaler_y = preprocessing.MinMaxScaler()

# Normalize the TOTAL_CONSUMPTION column
Y_df_normalized = Y_df_total_consumption.copy()  # Create a copy to avoid modifying the original DataFrame
Y_df_normalized['TOTAL_CONSUMPTION'] = min_max_scaler_y.fit_transform(Y_df_total_consumption)

# Save the scaler for later use
scaler_y_filename = os.path.join(dirs_inputs, "X_Y_Inputs", "min_max_scaler_y.pkl")
joblib.dump(min_max_scaler_y, scaler_y_filename)

# Specify the correct path for saving the normalized CSV
Y_df_normalized_output_string = os.path.join(dirs_dataframes, "Y_df_normalized.csv")

# Save only the TOTAL_CONSUMPTION column to CSV
Y_df_normalized[['TOTAL_CONSUMPTION']].to_csv(Y_df_normalized_output_string, index=False)

# %% [markdown]
# Feature Transformation

# %%
# Create a new DataFrame with columns 4 to 8 from X_df_no_calendar
features_for_trans_df = X_minmax_df.iloc[:, 3:8].copy()  # Adjusting for zero-based indexing
features_for_trans_df

def apply_transformations(column):
    transformations = {
        "Original": column,
        "Square": column ** 2,
        "Cube": column ** 3,
        "Sine": np.sin(column),
        "Cosine": np.cos(column),
        "Tangent": np.tan(column),
        "Logarithm": np.log(np.where(column > 0, column, np.nan)),  # Replace non-positive values with NaN
        "Square Root": np.sqrt(np.where(column >= 0, column, np.nan)),  # Replace negative values with NaN
        "Inverse": 1 / np.where(column != 0, column, np.nan),  # Replace zero values with NaN
    }
    return transformations

# Initialize an empty dataframe for transformed features
transformed_features_df = pd.DataFrame()

# Apply transformations for each column in the original dataframe
for column_name in features_for_trans_df.columns:
    transformations = apply_transformations(features_for_trans_df[column_name])
    for transform_name, transformed_column in transformations.items():
        transformed_features_df[f"{column_name} - {transform_name}"] = transformed_column

# Display the resulting dataframe
print(transformed_features_df)

# Specify the correct path for saving the CSV
dirs_dataframes = os.path.join(dirs_inputs, "X_Y_Inputs")
transformed_features_output_string = os.path.join(dirs_dataframes, "Transformed_Features.csv")
# Save the DataFrame to CSV
transformed_features_df.to_csv(transformed_features_output_string, index=False)
# Out:
#        Temp (C) - Original  Temp (C) - Square  Temp (C) - Cube  \
# 0                 0.010327           0.000107         0.000001
# 1                 0.027539           0.000758         0.000021
# 2                 0.027539           0.000758         0.000021
# 3                 0.017212           0.000296         0.000005
# 4                 0.043029           0.001852         0.000080
# ...                    ...                ...              ...
# 52579             0.419966           0.176371         0.074070
# 52580             0.418244           0.174928         0.073163
# 52581             0.418244           0.174928         0.073163
# 52582             0.418244           0.174928         0.073163
# 52583             0.419966           0.176371         0.074070
#
#        Temp (C) - Sine  Temp (C) - Cosine  Temp (C) - Tangent  \
# 0             0.010327           0.999947            0.010327
# 1             0.027535           0.999621            0.027546
# 2             0.027535           0.999621            0.027546
# 3             0.017211           0.999852            0.017213
# 4             0.043016           0.999074            0.043056
# ...                ...                ...                 ...
# 52579         0.407729           0.913103            0.446531
# 52580         0.406157           0.913803            0.444468
# 52581         0.406157           0.913803            0.444468
# 52582         0.406157           0.913803            0.444468
# 52583         0.407729           0.913103            0.446531
#
#        Temp (C) - Logarithm  Temp (C) - Square Root  Temp (C) - Inverse  \
# 0                 -4.572991                0.101622           96.833333
# 1                 -3.592162                0.165948           36.312500
# 2                 -3.592162                0.165948           36.312500
# 3                 -4.062166                0.131193           58.100000
# 4                 -3.145875                0.207435           23.240000
# ...                     ...                     ...                 ...
# 52579             -0.867583                0.648048            2.381148
# 52580             -0.871689                0.646718            2.390947
# 52581             -0.871689                0.646718            2.390947
# 52582             -0.871689                0.646718            2.390947
# 52583             -0.867583                0.648048            2.381148
#
#        Dew Point Temp (C) - Original  ...  Wind Spd (km/h) - Inverse  \
# 0                           0.058932  ...                   6.454545
# 1                           0.075506  ...                   6.454545
# 2                           0.075506  ...                   5.916667
# 3                           0.066298  ...                   6.454545
# 4                           0.090239  ...                  10.142857
# ...                              ...  ...                        ...
# 52579                       0.528545  ...                   5.071429
# 52580                       0.526703  ...                   4.437500
# 52581                       0.526703  ...                   3.550000
# 52582                       0.526703  ...                   3.550000
# 52583                       0.528545  ...                   3.736842
#
#        WIND CHILL CALCULATION - Original  WIND CHILL CALCULATION - Square  \
# 0                               0.073981                         0.005473
# 1                               0.090030                         0.008105
# 2                               0.084387                         0.007121
# 3                               0.080400                         0.006464
# 4                               0.132062                         0.017440
# ...                                  ...                              ...
# 52579                           0.447119                         0.199915
# 52580                           0.440433                         0.193981
# 52581                           0.431750                         0.186408
# 52582                           0.431750                         0.186408
# 52583                           0.435450                         0.189616
#
#        WIND CHILL CALCULATION - Cube  WIND CHILL CALCULATION - Sine  \
# 0                           0.000405                       0.073913
# 1                           0.000730                       0.089908
# 2                           0.000601                       0.084287
# 3                           0.000520                       0.080314
# 4                           0.002303                       0.131678
# ...                              ...                            ...
# 52579                       0.089386                       0.432369
# 52580                       0.085436                       0.426331
# 52581                       0.080481                       0.418461
# 52582                       0.080481                       0.418461
# 52583                       0.082568                       0.421818
#
#        WIND CHILL CALCULATION - Cosine  WIND CHILL CALCULATION - Tangent  \
# 0                             0.997265                          0.074116
# 1                             0.995950                          0.090274
# 2                             0.996442                          0.084588
# 3                             0.996770                          0.080574
# 4                             0.991293                          0.132835
# ...                                ...                               ...
# 52579                         0.901697                          0.479506
# 52580                         0.904567                          0.471310
# 52581                         0.908235                          0.460740
# 52582                         0.908235                          0.460740
# 52583                         0.906681                          0.465233
#
#        WIND CHILL CALCULATION - Logarithm  \
# 0                               -2.603948
# 1                               -2.407617
# 2                               -2.472341
# 3                               -2.520736
# 4                               -2.024486
# ...                                   ...
# 52579                           -0.804931
# 52580                           -0.819997
# 52581                           -0.839909
# 52582                           -0.839909
# 52583                           -0.831376
#
#        WIND CHILL CALCULATION - Square Root  WIND CHILL CALCULATION - Inverse
# 0                                  0.271994                         13.517001
# 1                                  0.300049                         11.107461
# 2                                  0.290494                         11.850159
# 3                                  0.283550                         12.437753
# 4                                  0.363403                          7.572217
# ...                                     ...                               ...
# 52579                              0.668669                          2.236543
# 52580                              0.663651                          2.270492
# 52581                              0.657077                          2.316157
# 52582                              0.657077                          2.316157
# 52583                              0.659886                          2.296477
#
# [52584 rows x 45 columns]

# %% [markdown]
# Renormalization of X_df after transformations (might not be required)

# %%
# Normalize the entire transformed_features_df
min_max_scaler_transformed = preprocessing.MinMaxScaler()

# Normalize all columns
transformed_features_normalized_df = transformed_features_df.copy()  # Create a copy to avoid modifying the original DataFrame
transformed_features_normalized_df = pd.DataFrame(min_max_scaler_transformed.fit_transform(transformed_features_df), columns=transformed_features_df.columns)

# Specify the correct path for saving the normalized CSV
dirs_dataframes = os.path.join(dirs_inputs, "X_Y_Inputs")
transformed_features_normalized_output_string = os.path.join(dirs_dataframes, "Transformed_Features_Normalized.csv")

# Save the normalized DataFrame to CSV
transformed_features_normalized_df.to_csv(transformed_features_normalized_output_string, index=False)
